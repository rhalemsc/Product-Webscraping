# %%
import pandas as pd
import re
import string
from bs4 import BeautifulSoup
import nltk
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import spacy
from nltk.util import ngrams
nltk.download('stopwords')
nltk.download('wordnet')
import unicodedata
import pyodbc
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rhale\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rhale\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 3000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 4)

# %%
# Function to clean up the data
def clean_string(text, stem="None"):

    final_string = ""

    # Make lower
    text = text.lower()

    # Remove line breaks
    text = re.sub(r'\n', ' ', text)

    # Remove puncuation
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)

    # Remove stop words
    text = text.split()
    useless_words = nltk.corpus.stopwords.words("english")
    useless_words = useless_words + ['hi', 'im']

    text_filtered = [word for word in text if not word in useless_words]

    # Remove numbers
    # text_filtered = [re.sub(r'\w*\d\w*', '', w) for w in text_filtered]

    # Stem or Lemmatize
    if stem == 'Stem':
        stemmer = PorterStemmer() 
        text_stemmed = [stemmer.stem(y) for y in text_filtered]
    elif stem == 'Lem':
        lem = WordNetLemmatizer()
        text_stemmed = [lem.lemmatize(y) for y in text_filtered]
    elif stem == 'Spacy':
        text_filtered = nlp(' '.join(text_filtered))
        text_stemmed = [y.lemma_ for y in text_filtered]
    else:
        text_stemmed = text_filtered

    final_string = ' '.join(text_stemmed)

    return final_string

# %%
English = spacy.load('en_core_web_sm')
English.max_length = 3000000

# %%
# Get the data
# Only getting the top 50 domains for testing purposes
conn = pyodbc.connect('Driver={SQL Server};'
                           'Server=asdf;'
                           'Database=asdf;'
                           'Trusted_Connection=yes;')

sql = """
SELECT --TOP(50)
Domain, STRING_AGG(PageText, ',') AS PageText
FROM CARFScrape
GROUP BY Domain
"""

df_cat_text_by_domain = pd.read_sql(sql, conn)
# Out:
# C:\Users\rhale\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# Apply the cleaning function to the PageText field to standardize, etc.
df_cat_text_by_domain['PageTextCleaned'] = df_cat_text_by_domain['PageText'].apply(lambda x: clean_string(x, stem='Lem'))
#df_cat_text_by_domain['PageTextCleaned'] = df_cat_text_by_domain['PageText']

# %%
# These are the keywords that we want to search for
key_words_orig = ['Metal buildings' , 'Building erection' , 'Erect metal buildings' 
, 'Structural engineering' , 'Structural design' , 'Structural fabrication' 
, 'Structural steel fabrication' , 'Structural framing construction' , 'Steel erection' 
, 'Steel building solutions' , 'Commercial' , 'Warehouse' 
, 'Industrial' , 'Aviation' , 'Agricultural' 
, 'Residential' , 'Building design' , 'Building steel structures' 
, 'Metal building design' , 'Tekla' , '3d building designer' 
, 'Metal building kit' , 'Steel building kit' , 'Pre-engineered steel building kit' 
, 'Red iron I-beam frames' , 'Roof purlins' , 'Wall girts' 
, 'Prefabricated structure']

key_words = ['3d building designer' , 'Building design' , 'Building erection' 
, 'Building steel structures' , 'Erect metal buildings' , 'Erector' 
, 'Metal building' , 'Metal building design' , 'Metal building kit' 
, 'Pre-engineered' , 'Pre-engineered steel building kit' , 'Prefabricated' 
, 'Prefabricated structure' , 'Purlin' , 'Red iron I-beam frames' 
, 'Roof purlins' , 'Steel building' , 'Steel building kit' 
, 'Steel building solutions' , 'Steel Erection' , 'Structural design' 
, 'Structural engineering' , 'Structural fabrication' , 'Structural framing construction' 
, 'Structural Steel Fabrication' , 'Tekla models' , 'Wall girts' 
, 'IAS 472' , 'IAS 473' , 'Associated Builder and Contractors' 
, 'Keystone Quality Assurance Program' , 'Metal Building Contractors & Erectors Association' , 'Metal Building Manufacturers Association' 
, 'Steel home' , 'CEES' , 'ZEES' , 'Z Purlin' , 'CEE' , 'ZEE' , 'Girts' , 'Z Girt' , 'Structural Sections' 
, 'Cold Formed Structural Sections' , 'Eave Struts' , 'CEE Purlin' , 'Red Oxide' , 'Bridge' , 'Highway' 
, 'Heavy steel', 'Commercial' , 'Warehouse' , 'Industrial' , 'Aviation' , 'Agricultural', 'Residential' ]

# %%
# Clean and standardize the keywords using the same function applied to the PageText
cleaned_key_words = []
for item in key_words:
    cleaned_key_words.append(clean_string(item, stem='Lem'))

# %%
#cleaned_key_words = key_words

# %%
# Create a new dataframe where each column is one of the keywords
data = pd.DataFrame(columns=cleaned_key_words)

# %%
data.columns
# Out:
# Index(['3d building designer', 'building design', 'building erection', 'building steel structure', 'erect metal building', 'erector', 'metal building', 'metal building design', 'metal building kit', 'preengineered', 'preengineered steel building kit', 'prefabricated', 'prefabricated structure', 'purlin', 'red iron ibeam frame', 'roof purlins', 'steel building', 'steel building kit', 'steel building solution', 'steel erection', 'structural design', 'structural engineering', 'structural fabrication', 'structural framing construction', 'structural steel fabrication', 'tekla model', 'wall girts', 'ia 472', 'ia 473', 'associated builder contractor', 'keystone quality assurance program', 'metal building contractor erectors association', 'metal building manufacturer association', 'steel home', 'cees', 'zee', 'z purlin', 'cee', 'zee', 'girts', 'z girt', 'structural section', 'cold formed structural section', 'eave strut', 'cee purlin', 'red oxide', 'bridge', 'highway', 'heavy steel', 'commercial', 'warehouse', 'industrial', 'aviation', 'agricultural', 'residential'], dtype='object')

# %%
# Add the Domain and PageTextCleaned columns to this new dataframe and re-order the columns
data['Domain'] = df_cat_text_by_domain['Domain']
data['PageTextCleaned'] = df_cat_text_by_domain['PageTextCleaned']

data = data[['Domain', 'PageTextCleaned', '3d building designer', 'building design', 'building erection', 'building steel structure', 'erect metal building', 'erector', 'metal building', 'metal building design', 'metal building kit', 'preengineered', 'preengineered steel building kit', 'prefabricated', 'prefabricated structure', 'purlin', 'red iron ibeam frame', 'roof purlins', 'steel building', 'steel building kit', 'steel building solution', 'steel erection', 'structural design', 'structural engineering', 'structural fabrication', 'structural framing construction', 'structural steel fabrication', 'tekla model', 'wall girts', 'ia 472', 'ia 473', 'associated builder contractor', 'keystone quality assurance program', 'metal building contractor erectors association', 'metal building manufacturer association', 'steel home', 'cees', 'zee', 'z purlin', 'cee', 'zee', 'girts', 'z girt', 'structural section', 'cold formed structural section', 'eave strut', 'cee purlin', 'red oxide', 'bridge', 'highway', 'heavy steel', 'commercial', 'warehouse', 'industrial', 'aviation', 'agricultural', 'residential']]

# %%
data.head(4)
# Out:
#           Domain                         PageTextCleaned                   3d building designer building design building erection building steel structure erect metal building erector metal building metal building design metal building kit preengineered preengineered steel building kit prefabricated prefabricated structure purlin red iron ibeam frame roof purlins steel building steel building kit steel building solution steel erection structural design structural engineering structural fabrication structural framing construction structural steel fabrication tekla model wall girts ia 472 ia 473 associated builder contractor keystone quality assurance program metal building contractor erectors association metal building manufacturer association steel home cees zee  zee  z purlin cee  zee  zee  girts z girt structural section cold formed structural section eave strut cee purlin red oxide bridge highway heavy steel commercial warehouse industrial aviation agricultural residential
# 0       advaluminum.com  70 capture 28 oct 2004 22 jul 2022 jan jul aug...          NaN                NaN              NaN                  NaN                    NaN            NaN        NaN                NaN                 NaN              NaN                    NaN                     NaN                NaN            NaN           NaN              NaN           NaN              NaN                   NaN                NaN              NaN                 NaN                    NaN                         NaN                           NaN                  NaN        NaN      NaN    NaN                NaN                             NaN                                      NaN                                         NaN                      NaN     NaN  NaN  NaN    NaN    NaN  NaN  NaN   NaN   NaN          NaN                      NaN                  NaN        NaN        NaN     NaN     NaN       NaN        NaN        NaN       NaN       NaN        NaN          NaN
# 1     agri-greenusa.com  16 capture 10 aug 2013 09 dec 2021 oct dec jan...          NaN                NaN              NaN                  NaN                    NaN            NaN        NaN                NaN                 NaN              NaN                    NaN                     NaN                NaN            NaN           NaN              NaN           NaN              NaN                   NaN                NaN              NaN                 NaN                    NaN                         NaN                           NaN                  NaN        NaN      NaN    NaN                NaN                             NaN                                      NaN                                         NaN                      NaN     NaN  NaN  NaN    NaN    NaN  NaN  NaN   NaN   NaN          NaN                      NaN                  NaN        NaN        NaN     NaN     NaN       NaN        NaN        NaN       NaN       NaN        NaN          NaN
# 2  allstateerectors.net  61 capture 29 dec 2010 07 dec 2021 jul nov dec...          NaN                NaN              NaN                  NaN                    NaN            NaN        NaN                NaN                 NaN              NaN                    NaN                     NaN                NaN            NaN           NaN              NaN           NaN              NaN                   NaN                NaN              NaN                 NaN                    NaN                         NaN                           NaN                  NaN        NaN      NaN    NaN                NaN                             NaN                                      NaN                                         NaN                      NaN     NaN  NaN  NaN    NaN    NaN  NaN  NaN   NaN   NaN          NaN                      NaN                  NaN        NaN        NaN     NaN     NaN       NaN        NaN        NaN       NaN       NaN        NaN          NaN
# 3         bennettpe.com  19 capture 19 apr 2013 22 dec 2021 jan dec jan...          NaN                NaN              NaN                  NaN                    NaN            NaN        NaN                NaN                 NaN              NaN                    NaN                     NaN                NaN            NaN           NaN              NaN           NaN              NaN                   NaN                NaN              NaN                 NaN                    NaN                         NaN                           NaN                  NaN        NaN      NaN    NaN                NaN                             NaN                                      NaN                                         NaN                      NaN     NaN  NaN  NaN    NaN    NaN  NaN  NaN   NaN   NaN          NaN                      NaN                  NaN        NaN        NaN     NaN     NaN       NaN        NaN        NaN       NaN       NaN        NaN          NaN

# %%
#data['metal building'] = data['PageTextCleaned'].str.contains('metal building')

# %%
# Now we're going to loop through all of the columns.
# For each column:
#    1. For each Domain, search for the column name in the PageTextCleaned
#    2. Assign True/False to the value of that column for that domain

# First get a list of columns to loop through, exclude the domain/text
col_list =  data.columns
col_list = col_list[2:]

# Now loop through them and identify the keywords
for col_name in col_list:
    data[col_name] = data['PageTextCleaned'].str.contains(col_name)

# %%
data.head(10)
# Out:
#           Domain                         PageTextCleaned                    3d building designer  building design  building erection  building steel structure  erect metal building  erector  metal building  metal building design  metal building kit  preengineered  preengineered steel building kit  prefabricated  prefabricated structure  purlin  red iron ibeam frame  roof purlins  steel building  steel building kit  steel building solution  steel erection  structural design  structural engineering  structural fabrication  structural framing construction  structural steel fabrication  tekla model  wall girts  ia 472  ia 473  associated builder contractor  keystone quality assurance program  metal building contractor erectors association  metal building manufacturer association  steel home  cees    zee    zee   z purlin   cee    zee    zee   girts  z girt  structural section  cold formed structural section  eave strut  cee purlin  red oxide  bridge  highway  heavy steel  commercial  warehouse  industrial  aviation  agricultural  residential
# 0       advaluminum.com  70 capture 28 oct 2004 22 jul 2022 jan jul aug...          False               True             False                  False                   False          False         True              False                 False            False                    False                   False               False             True          False             False          False             False                 False                False            False                 False                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False     True   True   True    False    True   True   True   True   False         False                     False                  True       False      False     False   False      False         True       True        True      False        True         True
# 1     agri-greenusa.com  16 capture 10 aug 2013 09 dec 2021 oct dec jan...          False              False             False                  False                   False          False         True              False                 False            False                    False                   False               False            False          False             False          False             False                 False                False            False                 False                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False   False  False  False  False   False         False                     False                 False       False      False      True   False      False         True      False       False      False        True         True
# 2  allstateerectors.net  61 capture 29 dec 2010 07 dec 2021 jul nov dec...          False              False             False                  False                   False           True        False              False                 False            False                    False                   False               False            False          False             False          False             False                 False                False            False                 False                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False   False  False  False  False   False         False                     False                 False       False      False     False   False      False        False      False       False      False       False        False
# 3         bennettpe.com  19 capture 19 apr 2013 22 dec 2021 jan dec jan...          False              False             False                  False                   False          False        False              False                 False            False                    False                   False               False            False          False             False          False             False                 False                False            False                  True                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False   False  False  False  False   False         False                     False                 False       False      False     False   False      False        False      False       False      False       False        False
# 4        bethel-eng.com  due planned power outage friday 114 8am1pm pst...          False               True             False                  False                   False          False         True               True                 False             True                    False                   False               False            False          False             False          False             False                 False                False             True                  True                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False   False  False  False  False   False         False                     False                 False       False      False     False   False      False         True       True        True      False       False         True
# 5         bmpmetals.net  69 capture 19 may 2001 13 mar 2022 jan mar apr...          False              False             False                  False                   False          False        False              False                 False            False                    False                   False               False            False          False             False          False             False                 False                False            False                 False                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False   False  False  False  False   False         False                     False                 False       False      False     False   False      False         True      False       False      False       False         True
# 6       brandonbell.com  2 capture 30 oct 2016 04 mar 2021 oct mar apr ...          False              False             False                  False                   False          False        False              False                 False            False                    False                   False               False            False          False             False          False             False                 False                False            False                 False                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False   True   True    False    True   True   True  False   False         False                     False                 False       False      False     False   False      False         True      False       False      False       False         True
# 7            cailor.com  15 capture 01 may 2011 23 dec 2021 sep dec jan...          False              False             False                  False                   False          False        False              False                 False            False                    False                   False               False            False          False             False          False             False                 False                False             True                  True                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False    True  False  False  False   False         False                     False                 False       False      False     False   False      False         True       True       False      False       False         True
# 8         callahan.aero  63 capture 15 oct 2010 28 nov 2021 jan nov dec...          False              False             False                  False                   False          False        False              False                 False            False                    False                   False               False            False          False             False          False             False                 False                False            False                  True                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False   False  False  False  False   False         False                     False                 False       False      False     False   False      False         True      False       False       True       False        False
# 9      callspaceage.com  29 capture 24 jul 2008 27 mar 2022 dec mar apr...          False              False             False                  False                   False          False         True              False                 False            False                    False                   False               False            False          False             False           True             False                 False                False            False                 False                   False                       False                           False                False        False     False   False              False                             False                                     False                                       False                      False    False  False  False    False   False  False  False  False   False         False                     False                 False       False      False     False   False      False        False      False       False      False       False        False

# %%
# Wide format is not too useful for doing analytics, convert to long format using melt
data_melted = data.melt(id_vars=['Domain', 'PageTextCleaned'], 
                        value_vars=col_list, 
                        value_name='KeywordOutcome', 
                        var_name='Keyword')

# %%
data_melted[['Domain', 'Keyword', 'KeywordOutcome']].to_csv('Quicken_Keywords.csv')

# %%
# Now for each domain we can get a count of keywords
data_melted_group = data_melted.groupby(['Domain','Keyword', 'KeywordOutcome'], as_index = False)\
     .agg(Count = ('Domain', 'count'))

# %%
# Most common keywords
# For Keyword=True, sum up how many website have that keyword
# Then calculate the percent that had the keyword
common_keywords = data_melted_group[data_melted_group['KeywordOutcome']==True]\
                                .groupby(['Keyword'], as_index=False)\
                                .agg(TotalTrue=('Count','sum'))
common_keywords['Percent'] = common_keywords['TotalTrue']/len(data)

# %%
domain_keywords = data_melted_group[data_melted_group['KeywordOutcome']==True]\
                                .groupby(['Domain'], as_index=False)\
                                .agg(TotalTrue=('Count','sum'))

# %%
domain_keywords.sort_values(by='TotalTrue', ascending=False)
# Out:
#                     Domain                 TotalTrue
# 31                  americanbuildings.com     26
# 289              kirbybuildingsystems.com     24
# 8                  acibuildingsystems.com     23
# 415                       reedsmetals.com     23
# 170                      edtengineers.com     22
# 537                       varcopruden.com     22
# 142              curvcosteelbuildings.com     19
# 32                  americansteelspan.com     19
# 166               dunnbuildingcompany.com     18
# 500                    structuresintl.com     18
# 483                         steellite.com     17
# 318                       macuchsteel.com     17
# 450                        silvercote.com     17
# 504                 supercellshelters.com     16
# 75                             bigbee.com     16
# 235                      hainesgipson.com     16
# 201                  flmetalbuildings.com     16
# 13                        advaluminum.com     16
# 17                         agcorsteel.com     16
# 379                        panelbuilt.com     16
# 172                          ehlinger.com     16
# 482                        steelincga.com     16
# 534                 usbuildingsdirect.com     16
# 295                 lariatsteeldesign.com     15
# 361               nashbuildingsystems.com     15
# 385                             pecga.com     15
# 108                    carportcentral.com     15
# 525            tridentbuildingsystems.com     14
# 78                     billerreinhart.com     14
# 489                           stellar.net     14
# 174                elephantstructures.com     14
# 501                  summit-companies.com     14
# 133         cornerstonebuildingbrands.com     14
# 564                 zuendtengineering.com     14
# 342                midsouthmechanical.com     14
# 544             waldropmetalbuildings.com     13
# 93                   burbyengineering.com     13
# 491                 stevens-wilkinson.com     13
# 23                 allsteel-buildings.com     13
# 442                       sfengineers.com     13
# 144             danbrownandassociates.com     13
# 30                    ameribuiltsteel.com     13
# 77                       bigredmetals.com     13
# 490             stevehallarchitecture.com     13
# 557               williamsengineering.com     13
# 348                           mmsainc.com     13
# 528                tysonsteelbuilding.com     12
# 481                      steelfab-inc.com     12
# 58                      bbmstructural.com     12
# 399           precisionmetalbuildings.com     12
# 72                           betcoinc.com     12
# 24                   alphacorporation.com     12
# 20                            allenfh.com     12
# 151                 dcimetalbuildings.com     12
# 152                            ddaeng.com     12
# 90                        bsdspeclink.com     12
# 47                          asdipsoft.com     12
# 313                m-squareassociates.biz     12
# 2                                 a-s.com     12
# 300                          lemartec.com     12
# 320                 majesticmetalsinc.com     12
# 509                       taylorviola.com     11
# 194                            fdh-is.com     11
# 182                 engineeringtechpa.com     11
# 22                      allstatesteel.com     11
# 74                           bhamfast.com     11
# 238                      hargrove-epc.com     11
# 103                          camurren.com     11
# 104               carolinacarportsinc.com     11
# 521                     titansunrooms.com     11
# 62                            beamcut.com     11
# 530                          uni-bilt.com     11
# 42                            ardurra.com     11
# 167                         duwemetal.com     11
# 136               cranstonengineering.com     11
# 38                  appliedscienceint.com     11
# 527                           twm-inc.com     11
# 141                    curryengineers.com     11
# 291                      ktmsolutions.com     10
# 485                steelsupplycompany.com     10
# 435                      safe-t-cover.com     10
# 469                 speathengineering.com     10
# 535                          uzuncase.com     10
# 352                      morganmetals.com     10
# 549                watsonsteelandiron.com     10
# 505                   superiorrigging.com     10
# 262                  industrial-steel.com     10
# 555                      wetherilleng.com     10
# 345                  millerclapperton.com     10
# 427                           rlh-llc.com     10
# 202                  florida-engineer.com     10
# 414                          redcofrp.com     10
# 115       centralsteelbuildingsystems.com     10
# 346                            mjmc.co.uk     10
# 63                             beargc.com     10
# 73                         bethel-eng.com     10
# 283                       jrtechgroup.com     10
# 160                       diversakore.com      9
# 175                  elite-structures.com      9
# 340                     metrosteelusa.com      9
# 446                    shelbyerectors.com      9
# 556                       wildstonecs.com      9
# 165                          dsisteel.com      9
# 332                       mcengineers.com      9
# 560                          woodseng.com      9
# 543                       vpcbuilders.com      9
# 61                           beac-inc.com      9
# 260                  imperialbuilders.com      9
# 258             imiindustrialservices.com      9
# 382              peachtreeresidential.com      9
# 60                             bdgllp.com      9
# 371                  onec1tynashville.com      9
# 384                           peaofsc.com      9
# 388                        permatherm.net      9
# 28                          altek-eng.com      9
# 381              pattilloconstruction.com      9
# 34                          amphionae.com      9
# 37                              apcte.com      9
# 428                             rlrpc.com      9
# 542                         vogelbldg.com      9
# 198                     fitengineering.us      9
# 310                             lrspc.net      9
# 298                              lbyd.com      8
# 280                      jonquilsteel.com      8
# 149                         davesteel.com      8
# 185                        esogrepair.com      8
# 190                        expbldgsys.com      8
# 169                          ebcsteel.com      8
# 241                              heci.com      8
# 232                           greisch.com      8
# 171               edwardsconstruction.com      8
# 421                      rgdengineers.com      8
# 314                         m1roofing.com      8
# 418                  remagensaferooms.com      8
# 331                            mbrstn.com      8
# 515             thecornerstonecompany.net      8
# 559                  wilsonstructural.com      8
# 493                      stonewalleng.com      8
# 40                 arcsteelframehomes.com      8
# 12                   adenacorporation.com      8
# 98                           caladesi.biz      8
# 126                 collinsstructural.com      8
# 81                         bluelinxco.com      8
# 56                          baydesign.com      8
# 89                          bryntesen.com      8
# 94                        buschdesign.com      8
# 529            ultimatesteelbuildings.com      8
# 41                      arcstructural.com      8
# 553                       weldonsteel.com      8
# 290               kloesel-engineering.com      7
# 43                             arehna.com      7
# 351                        morales-ce.com      7
# 79                 blackhawkengineers.com      7
# 444                    sgtengineering.com      7
# 209              formellaconstruction.com      7
# 545                        walkerreid.com      7
# 367                   northstatesteel.com      7
# 439                            seandi.com      7
# 225                   glaconstruction.com      7
# 277                 johnsonstructural.com      7
# 286                     kcl-solutions.com      7
# 92               bse-productsolutions.com      7
# 207                    fmsengineering.com      7
# 293                 labproinspections.com      7
# 192                 farriorsteelworks.com      7
# 413           realestatefloridanaples.com      7
# 309             loganpatriengineering.com      7
# 284                       jsdsolutions.in      7
# 87                        brandonbell.com      7
# 59                            bdg-usa.com      7
# 168                        eandssteel.com      7
# 387                        perigoneng.com      7
# 467             spacecoast-architects.com      7
# 155        dempseyconstructioncompany.com      7
# 148                         dardeneng.com      7
# 147                        dansmithpe.com      7
# 158                 destekengineering.com      7
# 447               sheridancorporation.com      7
# 244                        hitektruss.com      7
# 317                     maconplastics.com      7
# 153                deansteelbuildings.com      7
# 251                  hunterstructural.com      7
# 464                        southernae.com      7
# 368                            oakrep.com      7
# 255                      idilogistics.com      7
# 476                  springercontrols.com      7
# 323                        marchadams.com      7
# 335                 merchantironworks.com      7
# 263             innovative-structures.net      6
# 252                      husserlgroup.com      6
# 416                     reelfootmetal.com      6
# 215                     fremontwright.com      6
# 216                           fusefab.com      6
# 531                      unionlasteel.com      6
# 219                    gamblebuilders.com      6
# 248                          hornetsb.com      6
# 51                              bareng.ca      6
# 397                             pmass.com      6
# 245                          hmbsteel.com      6
# 360                            nannis.com      6
# 410                   raycoindustrial.com      6
# 226                      gormannaples.com      6
# 402                           prystup.com      6
# 80                 blaineconstruction.com      6
# 378                      pandawelding.com      6
# 533                     universaljobs.com      6
# 239               harrissteelerectors.com      6
# 391                 phoenixpaintingco.com      6
# 285                            kbkeng.com      6
# 519                 threadedfasteners.com      6
# 272                          jencofan.com      6
# 462               solarfoundationsusa.com      6
# 287                      kelcoroofing.com      6
# 299                             lcfwd.com      6
# 470                     spectrashield.com      6
# 161                      division5inc.com      6
# 311                       lucas-scott.com      6
# 11                        acunleashed.com      6
# 315                mackdavidbuildings.com      6
# 164                        dpcmemphis.com      6
# 474                            spirco.com      6
# 121        clarencetaylorconstruction.com      6
# 114             centralsteelbuildings.com      6
# 357                       mulhernkulp.com      6
# 173                     elephantbarns.com      6
# 468                   spacecoaststeel.com      6
# 302                      lhcengineers.com      6
# 6                      abs-structural.com      6
# 455                              sips.org      6
# 436                           saiengr.com      6
# 339            metrolinasteelerectors.com      6
# 337                  metalbuildinginc.com      6
# 88                 bridging-solutions.com      6
# 430                     robinbuilders.com      6
# 195                          fellerpe.com      6
# 193  fayettevillemetalbuildingsystems.com      6
# 96                             cailor.com      6
# 156               designbuildpartners.com      6
# 466            southernsteelengineers.com      6
# 296                            larion.net      6
# 499                structural-designs.com      6
# 184                  ervinengineering.com      6
# 438                             sdlal.com      6
# 53                          baronsign.com      5
# 261                 in-lineconsulting.net      5
# 265              interconbuildingcorp.com      5
# 347                             mjrdb.com      5
# 18                      agri-greenusa.com      5
# 370                        olive-arch.com      5
# 273              jimbarnalogandtimber.com      5
# 541                        vmerectors.com      5
# 275                           jlrdinc.com      5
# 353                       morrowsteel.com      5
# 365                      niblockhomes.com      5
# 48                         ashmorellc.com      5
# 359                         n-gineers.com      5
# 1                                5tco.com      5
# 292                  kunjconstruction.com      5
# 231                   greenstarpanels.com      5
# 256                 ietbuildinghealth.com      5
# 448                        shieldseng.com      5
# 112                          ceitampa.com      5
# 517                         themdgllc.com      5
# 211                          francepe.com      5
# 125               coastalmodulargroup.com      5
# 423                     richmondhonan.com      5
# 204                       fluhrerreed.com      5
# 203                    floridawelding.com      5
# 196                  fieldengineering.net      5
# 222                  generalprovision.com      5
# 254                            idi-tn.com      5
# 157              destefanoengineering.com      5
# 186                           ettfire.com      5
# 472                           speeler.com      5
# 477                         ssedesign.com      5
# 179                  energysaversfoam.com      5
# 441                       sentrysteel.com      5
# 411                             rbsga.com      5
# 412                         rdroofing.net      5
# 456                         slaysteel.com      5
# 233                    guillebeauiron.com      5
# 526                        twincityga.com      5
# 139                             csm-e.net      5
# 253                      ibisbuilding.com      5
# 70                         bermanbros.com      5
# 240                              hcbi.net      5
# 71                         bermancorp.com      5
# 130                  contracterectors.com      5
# 134                covenantdevelopment.us      5
# 401                 probuiltbuildings.com      5
# 405                         questengg.com      5
# 406                        quick-deck.com      5
# 386                       peloadcalcs.com      5
# 329              maxsouthconstruction.com      4
# 344                   millenniumwalls.com      4
# 480                          steelesi.com      4
# 562                       wyachtgroup.com      4
# 452                       simpsonengr.com      4
# 461                          softplan.com      4
# 554                    westmetroboard.com      4
# 460                        smithengco.com      4
# 558               wilmingtonmachinery.com      4
# 341                     mhparchitects.com      4
# 451                  silveriapainting.com      4
# 550                     wbconstruction.us      4
# 431                          ropacinc.com      4
# 546                   wallabysfabshop.com      4
# 417                          reigstad.com      4
# 383                  peakenergyonline.com      4
# 523                       tntcarports.com      4
# 520             timdurdenconstruction.com      4
# 375                            osteel.com      4
# 373                       orion-naval.com      4
# 398                pomonapipeproducts.com      4
# 363                  neptuneboatlifts.com      4
# 536                       valleybarns.com      4
# 514                       terratecinc.com      4
# 487                       steelvision.com      4
# 422                    richardandrice.com      4
# 511                tennesseepavilions.com      4
# 354                    mortonproducts.com      4
# 437              sanfordmetalbuilding.com      4
# 495                         strdetail.com      4
# 538                         vazirieng.com      4
# 440              seminole-landscaping.com      4
# 488                      steelworxusa.com      4
# 445                   shearstructural.com      4
# 0                             282roof.com      4
# 109                   cbcofcharleston.com      4
# 69                       beringyachts.com      4
# 84                        borderrebar.com      4
# 85                   boxboardproducts.com      4
# 102            cameronconstruction.com.au      4
# 107                     carolinasolar.com      4
# 221                  gbghconstruction.com      4
# 117                          chisel3d.com      4
# 122           clarksvillehomebuilders.com      4
# 128             constructionexecutive.com      4
# 259         impactwindowsanddoorspros.com      4
# 138                     crownsteelfab.com      4
# 250                   hudsoncustomfab.com      4
# 246                homeworksofalabama.com      4
# 243                heritageharborgolf.com      4
# 242                    heesassociates.com      4
# 145                  dandcbuildersinc.com      4
# 146                dannickconsultants.com      4
# 237                   hammettsteelllc.com      4
# 327                     marshall-team.com      4
# 163                       dostiehomes.com      4
# 181                   engineeredsteel.com      4
# 189     existingstructuresengineering.com      4
# 76                          bigcsteel.com      4
# 220                     garrisonsteel.com      4
# 64                             becdon.com      4
# 39                architectureplusllc.com      4
# 55                        bawarehouse.com      4
# 25                       alpinetowers.com      4
# 29                    amborstructures.com      4
# 46              arthurnobleproperties.com      4
# 19                  alcarconstructors.com      4
# 307                         litecrete.com      4
# 35                          anatekinc.com      4
# 306                   lincresearchinc.com      4
# 45                               arper.us      4
# 561                          woolfeng.com      3
# 14           advancedstructuraldesign.com      3
# 449                   shineelectrical.com      3
# 10                             act.claims      3
# 176                            emaeng.net      3
# 15                       aestructural.com      3
# 4                            aa-metal.com      3
# 188                          exactusa.com      3
# 3                           a2g-group.com      3
# 454                   sinkertreasures.com      3
# 565                             zumro.com      3
# 433            ryan-innovation-center.com      3
# 199               flatlanticironworks.com      3
# 200                         flattruss.com      3
# 424                         rjbaggett.com      3
# 206                           fmsaero.com      3
# 210                fortune-architects.com      3
# 213                   freedommachining.us      3
# 214                      freedomsteel.com      3
# 217                gageconstructionsc.com      3
# 548                        warp-drive.com      3
# 33                             amihhi.com      3
# 140                     cummingssigns.com      3
# 44                        arironworks.com      3
# 513             terramararchitectural.com      3
# 512               tennesseeriversteel.com      3
# 510                         tdgoodwin.com      3
# 86                brackenconstruction.com      3
# 507                  sykes-consulting.com      3
# 97                        caktusgroup.com      3
# 99                          callahan.aero      3
# 492                       stonesheets.com      3
# 105               carolinagreenhouses.com      3
# 110                           ccsicol.com      3
# 547                   walts-buildings.com      3
# 111                     ccsimagegroup.com      3
# 484                steelstormshelters.com      3
# 113                    centerpointmfg.com      3
# 119                          civicinc.com      3
# 473                     spinecarecary.com      3
# 123                      clearwaterco.com      3
# 471                 spectrumdesignusa.com      3
# 135                  craigsremodeling.com      3
# 518                   thepfeilcompany.com      3
# 328                      master-steel.net      3
# 159                    discipledesign.com      3
# 229               greenriverlogcabins.com      3
# 276                             jluca.com      3
# 281                       jordantruss.com      3
# 392                            piebox.com      3
# 376                   osteenbuildings.com      3
# 396                       plansonline.com      3
# 279                     jonesconcrete.com      3
# 301                  leslieindustries.com      3
# 390         pestructuresandassociates.com      3
# 278                joinerconstruction.com      3
# 249                  housmansaluminum.com      3
# 400                 prestressconcrete.com      3
# 288                  kenmillerguitars.com      3
# 364                    newwavepoolssc.com      3
# 395              pittman-construction.com      3
# 366                            nodust.com      3
# 372               onsearchinteractive.com      3
# 343                   midstatewelding.com      3
# 312                       lynchmykins.com      3
# 408        raleighwroughtironandfence.com      3
# 409                  randolphbuilders.com      3
# 336                merrellengineering.com      3
# 270                jburnsconstruction.com      3
# 282                       jorgefrases.com      2
# 479                  steelerectorsinc.com      2
# 268                    jamisonhomestn.com      2
# 116             chathamenterprisesinc.com      2
# 91                      bsdstructures.com      2
# 496                        stream-eng.com      2
# 503            suncoastinfrastructure.com      2
# 362                           nctlinc.com      2
# 106                carolinametal.webs.com      2
# 100                      callspaceage.com      2
# 497                   struc-engineers.com      2
# 223                  george-gina-lucy.com      2
# 294                    langelierpools.com      2
# 356                                msa.ie      2
# 304           lighthousechildrenshome.com      2
# 333                         mcqueense.com      2
# 7                    absolute-welding.com      2
# 9              act-operationsresearch.com      2
# 551                       wcengineers.com      2
# 338                           metalfx.net      2
# 319      magneticsandtransformergroup.com      2
# 316                      maconhousing.com      2
# 36                            andronx.com      2
# 540                  villafrancahomes.com      2
# 539                 vickersmetalworks.com      2
# 50                        atigroupinc.com      2
# 355            motleystructuraldesign.com      2
# 532              unitedhardwaredirect.com      2
# 52                    barfielddesigns.com      2
# 303                libertywoodworking.com      2
# 65                         bellequant.com      2
# 66                     benhambuilders.com      2
# 524                         trans4fed.com      2
# 67                 bennett-industries.com      2
# 297                          lazairon.com      2
# 82                          bmpmetals.net      2
# 83                              bmsi1.com      2
# 478                    steelbyskyline.com      2
# 271              jeffersonwoodworking.com      2
# 566               zurbuchconstruction.com      2
# 465            southernsteeldetailers.com      2
# 208         forensicinvestigationsllc.net      2
# 420                  reveleventcenter.com      2
# 143                       damoorecorp.com      2
# 393                piedmontmetalworks.com      2
# 257                            imcfab.com      2
# 212                 frazierhomedesign.com      2
# 380                    parkerpoolsinc.com      2
# 394                       pinewoodpro.com      2
# 443                     sgliquidmetal.com      2
# 429                 rnkmilton.wixsite.com      2
# 197               fishboneenterprises.net      2
# 132                   coriolisconsult.com      2
# 178                         emm-trace.com      2
# 234                hadrontechnologies.com      2
# 129                   constructwilson.com      2
# 224                       gipsonsteel.com      2
# 266                 iveysconstruction.com      2
# 187                      eversafe-usa.com      2
# 218          gamble-gamble-architects.com      2
# 180                       engconcepts.com      2
# 305                        limorsteel.com      1
# 350                          mohaneng.com      1
# 54                            basesix.com      1
# 308                       lizard-labs.com      1
# 349                   mockdevelopment.com      1
# 426                             rlcad.com      1
# 191                          fageneng.com      1
# 49                        astexhibits.com      1
# 228                           gpesinc.com      1
# 425                       rkpcservice.com      1
# 27                        altechpanel.com      1
# 205                   flyingfisherman.com      1
# 227                         gotobrand.net      1
# 330                          maysemfg.com      1
# 326                    markimerection.com      1
# 563                            zcrinc.com      1
# 325                           markiii.net      1
# 5                            ablenook.com      1
# 407                rackleyengineering.com      1
# 334            melvilletradingcompany.com      1
# 324                       markhannula.com      1
# 16                            afconde.com      1
# 403                 qualitymachinefab.com      1
# 322              manufacturingmethods.com      1
# 552                              weld.com      1
# 21                   allstateerectors.net      1
# 404                   quateindustrial.net      1
# 321               maniscustombuilders.com      1
# 419                         reroofusa.com      1
# 26                  altaengineeringco.com      1
# 432                    rwprecisioncnc.com      1
# 57                            bbcrane.com      1
# 377                overtonengineering.com      1
# 230           greensboroaquaticcenter.com      1
# 434                     sabodesigning.com      1
# 101               calvettiengineering.com      1
# 494            storagebuildingcompany.com      1
# 137                  crosstiesofocala.com      1
# 463                 soulattitudepress.com      1
# 274                  jlongcustomhomes.com      1
# 369                     oldlutzschool.com      1
# 486              steelsupplyofalabama.com      1
# 269                   jbrownleedesign.com      1
# 131                      corbettsauto.com      1
# 264                       inspectobot.com      1
# 118             choiceconcretewallsal.com      1
# 127                  concreteerectors.com      1
# 124                   clemmerdulcimer.com      1
# 374                     oscarcarvallo.com      1
# 120                          cks-tech.com      1
# 475                 sportcourtflorida.com      1
# 267                         ivybakery.com      1
# 459                          smgcs.church      1
# 458                    smadaengineers.com      1
# 498                       struct-engr.com      1
# 154                       dellcorning.com      1
# 236               halotechnologiesllc.com      1
# 522                     tmdarchitects.com      1
# 68                          bennettpe.com      1
# 516                 thedesignstandard.com      1
# 177        emeraldcoastcustomhomesinc.com      1
# 162                   dixonassociates.net      1
# 358              murrayconstructionco.com      1
# 508        tamparemodelingcontractors.com      1
# 457                       sloandesign.biz      1
# 150                      davis-church.com      1
# 506           sweatsportablebuildings.com      1
# 389                      persicahomes.com      1
# 95                  cadoutsourcinghub.com      1
# 453                          simsarch.com      1
# 502                    sunairproducts.net      1
# 247                  hookedsurfboards.com      1
# 183                      envirodesign.com      1

# %%
common_keywords.sort_values(by='TotalTrue', ascending=False)
# Out:
#                    Keyword                   TotalTrue  Percent
# 10                               commercial     414     0.6198
# 17                               industrial     327     0.4895
# 27                              residential     312     0.4671
# 7                                       cee     304     0.4551
# 3                                    bridge     202     0.3024
# 41                                warehouse     175     0.2620
# 35                   structural engineering     159     0.2380
# 4                           building design     145     0.2171
# 34                        structural design     129     0.1931
# 18                           metal building     118     0.1766
# 16                                  highway     116     0.1737
# 43                                      zee     108     0.1617
# 22                            preengineered      90     0.1347
# 2                                  aviation      81     0.1213
# 0                              agricultural      78     0.1168
# 29                           steel building      77     0.1153
# 13                                  erector      61     0.0913
# 23                            prefabricated      58     0.0868
# 32                           steel erection      48     0.0719
# 25                                   purlin      37     0.0554
# 38             structural steel fabrication      34     0.0509
# 9                                      cees      22     0.0329
# 14                                    girts      20     0.0299
# 33                               steel home      19     0.0284
# 19                    metal building design      17     0.0254
# 11                               eave strut      14     0.0210
# 36                   structural fabrication      14     0.0210
# 5                         building erection      14     0.0210
# 1             associated builder contractor      13     0.0195
# 20                       metal building kit      12     0.0180
# 21  metal building manufacturer association      11     0.0165
# 15                              heavy steel       9     0.0135
# 28                             roof purlins       7     0.0105
# 31                  steel building solution       7     0.0105
# 6                  building steel structure       5     0.0075
# 30                       steel building kit       5     0.0075
# 40                               wall girts       4     0.0060
# 12                     erect metal building       2     0.0030
# 37                       structural section       2     0.0030
# 26                                red oxide       2     0.0030
# 24                  prefabricated structure       2     0.0030
# 8                                cee purlin       1     0.0015
# 39                              tekla model       1     0.0015
# 42                                 z purlin       1     0.0015
